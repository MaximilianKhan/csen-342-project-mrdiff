# %%
# %matplotlib inline
from generate_tables import table1_results, table2_training, table3_runs, table4_differences

table1_results()
table2_training()
table3_runs()
table4_differences()
# Out:
#                Component               Paper                Ours
# 0    Trend decomposition          Cumulative            Residual
# 1      Reverse diffusion          DPM-Solver    DDPM (100 steps)
# 2       Mixup projection     Learned (Eq. 9)      Random weights
# 3  Signal reconstruction     sum(all stages)      predictions[0]
# 4       Kernel sizes / S  Per-dataset search  Fixed S=5, [5-201]

# %%
from generate_figures import figure1_loss_curves, figure2_forecasts, figure3_mae_comparison

figure1_loss_curves()    # Validation loss curves (2x2 grid, all 4 experiments)
figure2_forecasts()      # Forecast vs ground truth (2x2 grid from best run)
figure3_mae_comparison() # Bar chart: our MAE vs paper's MAE with gap annotations
